# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("abalone.csv")
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.nunique()
# Out:
# Sex                  3
# Length             134
# Diameter           111
# Height              51
# Whole weight      2429
# Shucked weight    1515
# Viscera weight     880
# Shell weight       926
# Rings               28
# dtype: int64

# %%
df.hist()
plt.tight_layout()

# %%
df["age"] = df["Rings"] + 1.5

# %%
df.drop('Rings', axis=1)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
mapping = {'M': 0, 'F': 1, 'I': 2}
df['Sex'] = df['Sex'].map(mapping)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
X = df.drop(['Rings', 'age'], axis=1)
y = df['age']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
sns.boxenplot(X_train['Viscera weight'])
# Out:
# <Axes: ylabel='Viscera weight'>

# %%
viscera_idx = X_train.loc[X_train['Viscera weight'] > 0.6].index
X_train.drop(viscera_idx, inplace=True)

# %%
sns.boxenplot(X_train['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
height_idx = X_train.loc[X_train['Height'] > 0.4].index
X_train.drop(height_idx, inplace=True)

# %%
X = df[['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight']]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

best_silhouette_score = -1
best_k = -1

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    cluster_labels = kmeans.labels_
    silhouette_avg = silhouette_score(X_pca, cluster_labels)
    print(f"K: {k} - Silhouette Score: {silhouette_avg}")
    if silhouette_avg > best_silhouette_score:
        best_silhouette_score = silhouette_avg
        best_k = k

print(f"Best Silhouette Score: {best_silhouette_score}")
print(f"Best K: {best_k}")
# Out:
# K: 2 - Silhouette Score: 0.5327596227439092
# K: 3 - Silhouette Score: 0.47995324835172887
# K: 4 - Silhouette Score: 0.45578418647728725
# K: 5 - Silhouette Score: 0.4378484040530765
# K: 6 - Silhouette Score: 0.4258062041234737
# K: 7 - Silhouette Score: 0.3860990404165698
# K: 8 - Silhouette Score: 0.3588297702713474
# K: 9 - Silhouette Score: 0.32569952848586176
# K: 10 - Silhouette Score: 0.31705041605055767
# Best Silhouette Score: 0.5327596227439092
# Best K: 2

# %%
kmeans_best = KMeans(n_clusters=best_k, random_state=42)
kmeans_best.fit(X_pca)
cluster_labels = kmeans.labels_

# %%
X_pca
# Out:
# array([[-1.75601906, -0.39053219],
#        [-3.36273423, -0.10515295],
#        [-0.48233832,  0.25205488],
#        ...,
#        [ 2.16737289,  0.72401042],
#        [ 1.647501  , -0.30516552],
#        [ 4.89454204, -0.70579789]])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=cluster_labels, alpha=0.5)
plt.title(f"Clustering results for best KMeans {best_k}")
plt.xlabel("Principal component 1")
plt.ylabel("Principal component 2")
plt.tight_layout()
plt.colorbar(label="cluster")
plt.show()

# %%
X = df.drop(['Rings', 'age'], axis=1)
y = df['age']
X
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       0   0.455     0.365   0.095        0.5140          0.2245
# 1       0   0.350     0.265   0.090        0.2255          0.0995
# 2       1   0.530     0.420   0.135        0.6770          0.2565
# 3       0   0.440     0.365   0.125        0.5160          0.2155
# 4       2   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    1   0.565     0.450   0.165        0.8870          0.3700
# 4173    0   0.590     0.440   0.135        0.9660          0.4390
# 4174    0   0.600     0.475   0.205        1.1760          0.5255
# 4175    1   0.625     0.485   0.150        1.0945          0.5310
# 4176    0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
accuracy = mean_squared_error(y_test, y_pred)
print(f"MSE: {accuracy}")
# Out:
# MSE: 4.806170791152266

# %%
sample_input = [[0,	0.455,	0.365,	0.095,	0.5140,	0.2245,	0.1010,	0.1500]]
pred = lr.predict(sample_input)
print(pred)
# Out:
# [10.73409618]
# C:\Users\sselc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
